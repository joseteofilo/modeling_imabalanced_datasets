# %%
# Python libraries are imported
import numpy as np
import pandas as pd
import pandas_profiling
import math
from rdkit.Chem import PandasTools
from IPython.display import HTML
# Out:
# RDKit WARNING: [16:10:55] Enabling RDKit 2019.09.2 jupyter extensions

# %%
# load molecules
data1 = "../data/A2780.sdf"
data2 = "../data/CCRF-CEM.sdf"
data3 = "../data/DU-145.sdf"
data4 = "../data/HCT-15.sdf"
data5 = "../data/KB.sdf"
data6 = "../data/LoVo.sdf"
data7 = "../data/PC-3.sdf"
data8 = "../data/SK-OV-3.sdf"

# %%
# Convert the SDF file to a dataframe with smiles 
compound_df1 = PandasTools.LoadSDF(data1, smilesName='smiles', includeFingerprints=False)
compound_df2 = PandasTools.LoadSDF(data2, smilesName='smiles', includeFingerprints=False)
compound_df3 = PandasTools.LoadSDF(data3, smilesName='smiles', includeFingerprints=False)
compound_df4 = PandasTools.LoadSDF(data4, smilesName='smiles', includeFingerprints=False)
compound_df5 = PandasTools.LoadSDF(data5, smilesName='smiles', includeFingerprints=False)
compound_df6 = PandasTools.LoadSDF(data6, smilesName='smiles', includeFingerprints=False)
compound_df7 = PandasTools.LoadSDF(data7, smilesName='smiles', includeFingerprints=False)
compound_df8 = PandasTools.LoadSDF(data8, smilesName='smiles', includeFingerprints=False)

# %%
# Check the number of entries
print(len(compound_df1))
print(len(compound_df2))
print(len(compound_df3))
print(len(compound_df4))
print(len(compound_df5))
print(len(compound_df6))
print(len(compound_df7))
print(len(compound_df8))
# Out:
# 2255
# 3047
# 2512
# 994
# 2731
# 1120
# 4294
# 1589

# %%
# Check clolumns
list(compound_df1)
list(compound_df2)
list(compound_df3)
list(compound_df4)
list(compound_df5)
list(compound_df6)
list(compound_df7)
list(compound_df8)
# Out:
# ['pIC50', 'ChEMBL_ID', 'ID', 'smiles', 'ROMol']

# %%
# Float column 'pIC50'
compound_df1["pIC50"] = compound_df1["pIC50"].astype(float)
compound_df2["pIC50"] = compound_df2["pIC50"].astype(float)
compound_df3["pIC50"] = compound_df3["pIC50"].astype(float)
compound_df4["pIC50"] = compound_df4["pIC50"].astype(float)
compound_df5["pIC50"] = compound_df5["pIC50"].astype(float)
compound_df6["pIC50"] = compound_df6["pIC50"].astype(float)
compound_df7["pIC50"] = compound_df7["pIC50"].astype(float)
compound_df8["pIC50"] = compound_df8["pIC50"].astype(float)

# %%
# Round values in the column 'pIC50'
decimals = 2 
compound_df1["pIC50"] = [round(x, decimals) for x in compound_df1["pIC50"]]
compound_df2["pIC50"] = [round(x, decimals) for x in compound_df2["pIC50"]]
compound_df3["pIC50"] = [round(x, decimals) for x in compound_df3["pIC50"]]
compound_df4["pIC50"] = [round(x, decimals) for x in compound_df4["pIC50"]]
compound_df5["pIC50"] = [round(x, decimals) for x in compound_df5["pIC50"]]
compound_df6["pIC50"] = [round(x, decimals) for x in compound_df6["pIC50"]]
compound_df7["pIC50"] = [round(x, decimals) for x in compound_df7["pIC50"]]
compound_df8["pIC50"] = [round(x, decimals) for x in compound_df8["pIC50"]]

# %%
# Remove columns
compound_df1 = compound_df1.drop(['ROMol'], axis=1)
compound_df2 = compound_df2.drop(['ROMol'], axis=1)
compound_df3 = compound_df3.drop(['ROMol'], axis=1)
compound_df4 = compound_df4.drop(['ROMol'], axis=1)
compound_df5 = compound_df5.drop(['ROMol'], axis=1)
compound_df6 = compound_df6.drop(['ROMol'], axis=1)
compound_df7 = compound_df7.drop(['ROMol'], axis=1)
compound_df8 = compound_df8.drop(['ROMol'], axis=1)

# %% [markdown]
# ## Exploring data set cell line "A2780" - Ovarian carcinoma cells

# %%
# Exploring data
from pandas_profiling import ProfileReport
profile = ProfileReport(compound_df1, title='Pandas Profiling Report', html={'style':{'full_width':True}})
profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

pIC50s = np.array(compound_df1["pIC50"])
# Remove some dirty data from the dataset
pIC50s = [pIC50 for pIC50 in pIC50s if pIC50 != '']
n, bins, patches = plt.hist(pIC50s, 100, facecolor='green', alpha=0.75)
plt.xlabel('Measured pIC50')
plt.ylabel('Number of compounds')
plt.title(r'Histogram of pIC50 Values')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')

# %%
sns.distplot(compound_df1["pIC50"])
plt.xlabel("pIC50")
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
# %matplotlib inline
# %pylab inline
from IPython.display import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
scatter(compound_df1['pIC50'],compound_df1['pIC50'])

# %% [markdown]
# ## Exploring data set cell line "CCRF-CEM" - T‑cell leukemia

# %%
# Exploring data
from pandas_profiling import ProfileReport
profile = ProfileReport(compound_df2, title='Pandas Profiling Report', html={'style':{'full_width':True}})
profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

pIC50s = np.array(compound_df2["pIC50"])
# Remove some dirty data from the dataset
pIC50s = [pIC50 for pIC50 in pIC50s if pIC50 != '']
n, bins, patches = plt.hist(pIC50s, 100, facecolor='green', alpha=0.75)
plt.xlabel('Measured pIC50')
plt.ylabel('Number of compounds')
plt.title(r'Histogram of pIC50 Values')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')

sns.distplot(compound_df2["pIC50"])
plt.xlabel("pIC50")
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
# %matplotlib inline
# %pylab inline
from IPython.display import Image

scatter(compound_df2['pIC50'],compound_df2['pIC50'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Exploring data set cell line "DU‑145" - Prostate carcinoma

# %%
# Exploring data
from pandas_profiling import ProfileReport
profile = ProfileReport(compound_df3, title='Pandas Profiling Report', html={'style':{'full_width':True}})
profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

pIC50s = np.array(compound_df3["pIC50"])
# Remove some dirty data from the dataset
pIC50s = [pIC50 for pIC50 in pIC50s if pIC50 != '']
n, bins, patches = plt.hist(pIC50s, 100, facecolor='green', alpha=0.75)
plt.xlabel('Measured pIC50')
plt.ylabel('Number of compounds')
plt.title(r'Histogram of pIC50 Values')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')

sns.distplot(compound_df3["pIC50"])
plt.xlabel("pIC50")
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
# %matplotlib inline
# %pylab inline
from IPython.display import Image

scatter(compound_df3['pIC50'],compound_df3['pIC50'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Exploring data set cell line "HCT‑15" - Colon adenocarcinoma cells

# %%
# Exploring data
from pandas_profiling import ProfileReport
profile = ProfileReport(compound_df4, title='Pandas Profiling Report', html={'style':{'full_width':True}})
profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

pIC50s = np.array(compound_df4["pIC50"])
# Remove some dirty data from the dataset
pIC50s = [pIC50 for pIC50 in pIC50s if pIC50 != '']
n, bins, patches = plt.hist(pIC50s, 100, facecolor='green', alpha=0.75)
plt.xlabel('Measured pIC50')
plt.ylabel('Number of compounds')
plt.title(r'Histogram of pIC50 Values')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')

sns.distplot(compound_df4["pIC50"])
plt.xlabel("pIC50")
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
# %matplotlib inline
# %pylab inline
from IPython.display import Image

scatter(compound_df4['pIC50'],compound_df4['pIC50'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Exploring data set cell line "KB" - Squamous cell carcinoma

# %%
# Exploring data
from pandas_profiling import ProfileReport
profile = ProfileReport(compound_df5, title='Pandas Profiling Report', html={'style':{'full_width':True}})
profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

pIC50s = np.array(compound_df5["pIC50"])
# Remove some dirty data from the dataset
pIC50s = [pIC50 for pIC50 in pIC50s if pIC50 != '']
n, bins, patches = plt.hist(pIC50s, 100, facecolor='green', alpha=0.75)
plt.xlabel('Measured pIC50')
plt.ylabel('Number of compounds')
plt.title(r'Histogram of pIC50 Values')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')

sns.distplot(compound_df5["pIC50"])
plt.xlabel("pIC50")
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
# %matplotlib inline
# %pylab inline
from IPython.display import Image

scatter(compound_df5['pIC50'],compound_df5['pIC50'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Exploring data set cell line "LoVo" - Colon adenocarcinoma cells

# %%
# Exploring data
from pandas_profiling import ProfileReport
profile = ProfileReport(compound_df6, title='Pandas Profiling Report', html={'style':{'full_width':True}})
profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

pIC50s = np.array(compound_df6["pIC50"])
# Remove some dirty data from the dataset
pIC50s = [pIC50 for pIC50 in pIC50s if pIC50 != '']
n, bins, patches = plt.hist(pIC50s, 100, facecolor='green', alpha=0.75)
plt.xlabel('Measured pIC50')
plt.ylabel('Number of compounds')
plt.title(r'Histogram of pIC50 Values')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')

sns.distplot(compound_df6["pIC50"])
plt.xlabel("pIC50")
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
# %matplotlib inline
# %pylab inline
from IPython.display import Image

scatter(compound_df6['pIC50'],compound_df6['pIC50'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Exploring data set cell line "PC-3" - Prostate carcinoma cells

# %%
# Exploring data
from pandas_profiling import ProfileReport
profile = ProfileReport(compound_df7, title='Pandas Profiling Report', html={'style':{'full_width':True}})
profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

pIC50s = np.array(compound_df7["pIC50"])
# Remove some dirty data from the dataset
pIC50s = [pIC50 for pIC50 in pIC50s if pIC50 != '']
n, bins, patches = plt.hist(pIC50s, 100, facecolor='green', alpha=0.75)
plt.xlabel('Measured pIC50')
plt.ylabel('Number of compounds')
plt.title(r'Histogram of pIC50 Values')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')

sns.distplot(compound_df7["pIC50"])
plt.xlabel("pIC50")
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
# %matplotlib inline
# %pylab inline
from IPython.display import Image

scatter(compound_df7['pIC50'],compound_df7['pIC50'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Exploring data set cell line "SK-OV-3" - Ovarian carcinoma cells

# %%
# Exploring data
from pandas_profiling import ProfileReport
profile = ProfileReport(compound_df8, title='Pandas Profiling Report', html={'style':{'full_width':True}})
profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

pIC50s = np.array(compound_df8["pIC50"])
# Remove some dirty data from the dataset
pIC50s = [pIC50 for pIC50 in pIC50s if pIC50 != '']
n, bins, patches = plt.hist(pIC50s, 100, facecolor='green', alpha=0.75)
plt.xlabel('Measured pIC50')
plt.ylabel('Number of compounds')
plt.title(r'Histogram of pIC50 Values')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')

sns.distplot(compound_df8["pIC50"])
plt.xlabel("pIC50")
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
# %matplotlib inline
# %pylab inline
from IPython.display import Image

scatter(compound_df8['pIC50'],compound_df8['pIC50'])
# Out:
# Populating the interactive namespace from numpy and matplotlib
